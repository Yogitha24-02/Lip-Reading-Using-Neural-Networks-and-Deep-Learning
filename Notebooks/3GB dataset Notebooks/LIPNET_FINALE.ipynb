# %%
for i in os.listdir('/content/drive/MyDrive/final_lipnet_dataset'):
  if len(os.listdir('/content/drive/MyDrive/final_lipnet_dataset/'+i))==0:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fe808bac3dc8> in <cell line: 1>()
# ----> 1 for i in os.listdir('/content/drive/MyDrive/final_lipnet_dataset'):
#       2   if len(os.listdir('/content/drive/MyDrive/final_lipnet_dataset/'+i))==0:
#       3     print(i)
#
# NameError: name 'os' is not defined

# %%
import os

# %%
import shutil

# %%
for i in os.listdir('/content/drive/MyDrive/final_lipnet_dataset'):
  if len(os.listdir('/content/drive/MyDrive/final_lipnet_dataset/'+i))==0:
    print('/content/drive/MyDrive/final_lipnet_dataset/'+i)
    shutil.rmtree('/content/drive/MyDrive/final_lipnet_dataset/'+i)
# Out:
# /content/drive/MyDrive/final_lipnet_dataset/mdab0_sx229
# /content/drive/MyDrive/final_lipnet_dataset/mbjk0_sx275
# /content/drive/MyDrive/final_lipnet_dataset/mccs0_sx389
# /content/drive/MyDrive/final_lipnet_dataset/mtas1_sx298
# /content/drive/MyDrive/final_lipnet_dataset/mtas1_sx388
# /content/drive/MyDrive/final_lipnet_dataset/mtas1_sa1
# /content/drive/MyDrive/final_lipnet_dataset/mtas1_si1473
# /content/drive/MyDrive/final_lipnet_dataset/mtas1_sa2
# /content/drive/MyDrive/final_lipnet_dataset/felc0_sa2
# /content/drive/MyDrive/final_lipnet_dataset/mcem0_si768
# /content/drive/MyDrive/final_lipnet_dataset/mcem0_sx228
# /content/drive/MyDrive/final_lipnet_dataset/mcem0_si1398
# /content/drive/MyDrive/final_lipnet_dataset/mcem0_sa1
# /content/drive/MyDrive/final_lipnet_dataset/mcem0_sx48
# /content/drive/MyDrive/final_lipnet_dataset/faks0_sx403
# /content/drive/MyDrive/final_lipnet_dataset/mdbb0_sx25
# /content/drive/MyDrive/final_lipnet_dataset/mdbb0_sa1
# ...

# %%
print(len(os.listdir('/content/drive/MyDrive/final_lipnet_dataset/')))
# Out:
# 258

# %%
cropping_dictionary = {'mabw0_si1230': (216, 212, 286, 252),
 'fjwb0_sx95': (223, 211, 293, 251),
 'mreb0_sx25': (212, 230, 282, 270),
 'fdrd1_si2149': (217, 245, 287, 285),
 'mpdf0_si1542': (238, 222, 308, 262),
 'mpdf0_sa2': (243, 216, 313, 256),
 'mpdf0_sa1': (239, 214, 309, 254),
 'mpdf0_sx192': (221, 202, 291, 242),
 'mpdf0_sx102': (238, 218, 308, 258),
 'mpdf0_si2172': (238, 220, 308, 260),
 'mpdf0_si912': (239, 220, 309, 260),
 'mreb0_sx295': (218, 217, 288, 257),
 'mreb0_sa2': (218, 244, 288, 284),
 'mreb0_sa1': (217, 241, 287, 281),
 'mreb0_si745': (202, 239, 272, 279),
 'mreb0_sx115': (212, 239, 282, 279),
 'mreb0_sx385': (217, 216, 287, 256),
 'mreb0_si1375': (223, 281, 293, 321),
 'mreb0_sx205': (217, 228, 287, 268),
 'mjar0_si728': (218, 222, 288, 262),
 'mjar0_si1988': (244, 223, 314, 263),
 'mjar0_si2247': (244, 222, 314, 262),
 'mjar0_sa1': (234, 215, 304, 255),
 'mjar0_sx278': (222, 213, 292, 253),
 'mjar0_sx188': (215, 231, 285, 271),
 'mjar0_sx368': (225, 209, 295, 249),
 'mjar0_sa2': (239, 218, 309, 258),
 'mjar0_sx98': (210, 203, 280, 243),
 'mjar0_sx8': (216, 204, 286, 244),
 'mmdb1_sx275': (218, 198, 288, 238),
 'mmdb1_sa1': (221, 253, 291, 293),
 'mmdb1_si995': (216, 236, 286, 276),
 'mmdb1_si2255': (214, 230, 284, 270),
 'mmdb1_sa2': (218, 249, 288, 289),
 'mmdb1_sx365': (214, 203, 284, 243),
 'mmdb1_sx185': (219, 239, 289, 279),
 'mmdb1_sx5': (216, 192, 286, 232),
 'mmdb1_sx95': (215, 206, 285, 246),
 'mwbt0_sx383': (221, 235, 291, 275),
 'mwbt0_sa1': (211, 254, 281, 294),
 'mwbt0_sa2': (213, 249, 283, 289),
 'mwbt0_sx293': (224, 227, 294, 267),
 'mwbt0_sx23': (220, 233, 290, 273),
 'mwbt0_si923': (218, 253, 288, 293),
 'mwbt0_si1553': (212, 254, 282, 294),
 'mwbt0_sx203': (218, 217, 288, 257),
 'mdab0_si1039': (217, 243, 287, 283),
 'mdab0_sa1': (222, 223, 292, 263),
 'mdab0_sx319': (218, 198, 288, 238),
 'mdab0_si1669': (220, 240, 290, 280),
 'mdab0_sx139': (221, 229, 291, 269),
 'mdab0_si2299': (221, 227, 291, 267),
 'fkms0_si1490': (222, 270, 292, 310),
 'fkms0_sa2': (215, 264, 285, 304),
 'mdab0_sx49': (216, 208, 286, 248),
 'fkms0_sa1': (210, 253, 280, 293),
 'mdab0_sx409': (216, 210, 286, 250),
 'fkms0_sx140': (215, 267, 285, 307),
 'fkms0_sx410': (208, 262, 278, 302),
 'fkms0_sx230': (222, 282, 292, 322),
 'fkms0_si860': (213, 276, 283, 316),
 'fkms0_sx320': (220, 273, 290, 313),
 'fkms0_si2120': (208, 271, 278, 311),
 'mdld0_si1543': (233, 251, 303, 291),
 'mdld0_sa2': (229, 236, 299, 276),
 'mdld0_sx193': (220, 215, 290, 255),
 'mdld0_sa1': (229, 251, 299, 291),
 'mdld0_si913': (231, 243, 301, 283),
 'mdld0_si2173': (237, 248, 307, 288),
 'mdld0_sx13': (221, 231, 291, 271),
 'mdld0_sx373': (214, 222, 284, 262),
 'mdld0_sx283': (218, 219, 288, 259),
 'mjsw0_sa2': (248, 227, 318, 267),
 'mjsw0_sa1': (249, 227, 319, 267),
 'mjsw0_sx290': (225, 209, 295, 249),
 'mjsw0_sx200': (224, 192, 294, 232),
 'mjsw0_sx20': (223, 199, 293, 239),
 'mjsw0_si1640': (249, 227, 319, 267),
 'mjsw0_sx380': (226, 208, 296, 248),
 'mjsw0_si1010': (250, 225, 320, 265),
 'mjsw0_sx110': (245, 221, 315, 261),
 'mbjk0_sx185': (188, 206, 258, 246),
 'mbjk0_si1175': (194, 209, 264, 249),
 'mbjk0_sa2': (203, 214, 273, 254),
 'mbjk0_si545': (186, 201, 256, 241),
 'mbjk0_sx5': (217, 248, 287, 288),
 'mbjk0_sa1': (198, 215, 268, 255),
 'mbjk0_si2128': (193, 204, 263, 244),
 'mbjk0_sx95': (224, 240, 294, 280),
 'mstk0_si1024': (214, 235, 284, 275),
 'mstk0_si2222': (212, 235, 282, 275),
 'mstk0_si2284': (213, 230, 283, 270),
 'mstk0_sx124': (213, 239, 283, 279),
 'mstk0_sx214': (223, 220, 293, 260),
 'mstk0_sx394': (233, 217, 303, 257),
 'mstk0_sx304': (227, 209, 297, 249),
 'mstk0_sx34': (232, 212, 302, 252),
 'mstk0_sa1': (218, 238, 288, 278),
 'fadg0_si1909': (224, 194, 294, 234),
 'fadg0_si649': (214, 193, 284, 233),
 'fadg0_sa2': (218, 187, 288, 227),
 'fadg0_sa1': (221, 196, 291, 236),
 'fadg0_sx109': (217, 203, 287, 243),
 'mrcz0_sa2': (227, 226, 297, 266),
 'mrcz0_si1541': (230, 243, 300, 283),
 'mrcz0_si911': (227, 217, 297, 257),
 'fadg0_sx379': (224, 198, 294, 238),
 'mrcz0_si2171': (230, 215, 300, 255),
 'mrcz0_sa1': (223, 223, 293, 263),
 'fadg0_sx289': (228, 205, 298, 245),
 'mrcz0_sx371': (228, 221, 298, 261),
 'mrcz0_sx191': (220, 212, 290, 252),
 'mrcz0_sx11': (217, 212, 287, 252),
 'mrcz0_sx101': (230, 227, 300, 267),
 'mrcz0_sx281': (229, 224, 299, 264),
 'mccs0_si839': (225, 236, 295, 276),
 'mccs0_sx119': (221, 240, 291, 280),
 'fjwb0_sa2': (222, 203, 292, 243),
 'mccs0_sx299': (219, 250, 289, 290),
 'fjwb0_si1265': (217, 210, 287, 250),
 'mccs0_sa2': (215, 231, 285, 271),
 'mccs0_sx209': (228, 234, 298, 274),
 'fjwb0_sa1': (223, 199, 293, 239),
 'fjwb0_sx185': (206, 214, 276, 254),
 'fjwb0_sx365': (218, 207, 288, 247),
 'fjwb0_sx275': (222, 213, 292, 253),
 'fjwb0_si992': (207, 211, 277, 251),
 'fjwb0_si635': (218, 203, 288, 243),
 'mrgg0_sx389': (230, 241, 300, 281),
 'mrgg0_sx209': (214, 236, 284, 276),
 'mtas1_sx28': (221, 169, 291, 209),
 'mtas1_sx118': (238, 208, 308, 248),
 'mtas1_sx208': (224, 174, 294, 214),
 'mtas1_si838': (241, 204, 311, 244),
 'mtas1_si2098': (241, 204, 311, 244),
 'mabw0_si1664': (214, 202, 284, 242),
 'mabw0_sa1': (216, 211, 286, 251),
 'mabw0_sx314': (238, 214, 308, 254),
 'mabw0_sx44': (220, 197, 290, 237),
 'mabw0_sa2': (212, 210, 282, 250),
 'mabw0_sx134': (217, 212, 287, 252),
 'mabw0_sx224': (231, 213, 301, 253),
 'mabw0_si2294': (219, 209, 289, 249),
 'felc0_sx216': (229, 209, 299, 249),
 'felc0_sx396': (209, 211, 279, 251),
 'felc0_si756': (200, 225, 270, 265),
 'felc0_sx126': (197, 231, 267, 271),
 'felc0_sa1': (214, 227, 284, 267),
 'felc0_si1386': (206, 228, 276, 268),
 'felc0_si2016': (205, 229, 275, 269),
 'fdac1_sx34': (223, 226, 293, 266),
 'fdac1_sx304': (220, 227, 290, 267),
 'fdac1_sx394': (226, 236, 296, 276),
 'fdac1_sx214': (218, 241, 288, 281),
 'fdac1_sx124': (204, 272, 274, 312),
 'fdac1_sa2': (221, 253, 291, 293),
 'fdac1_sa1': (218, 253, 288, 293),
 'fdac1_si844': (201, 271, 271, 311),
 'fpkt0_sx278': (200, 237, 270, 277),
 'fpkt0_sx8': (212, 239, 282, 279),
 'fpkt0_si2168': (215, 248, 285, 288),
 'fpkt0_sa1': (217, 237, 287, 277),
 'fpkt0_sx368': (201, 233, 271, 273),
 'fpkt0_sx98': (206, 236, 276, 276),
 'fcmh0_si2084': (223, 204, 293, 244),
 'fcmh0_sx14': (227, 222, 297, 262),
 'fcmh0_si1454': (224, 212, 294, 252),
 'fcmh0_si824': (218, 202, 288, 242),
 'fcmh0_sa2': (222, 203, 292, 243),
 'fcmh0_sx374': (221, 226, 291, 266),
 'fcmh0_sx284': (221, 219, 291, 259),
 'fcmh0_sx194': (228, 226, 298, 266),
 'fcmh0_sx104': (224, 206, 294, 246),
 'fcmh0_sa1': (223, 212, 293, 252),
 'fedw0_sx184': (219, 194, 289, 234),
 'fedw0_sx274': (211, 189, 281, 229),
 'fedw0_sa1': (223, 197, 293, 237),
 'fedw0_sx94': (224, 211, 294, 251),
 'fedw0_si1714': (220, 208, 290, 248),
 'fedw0_sx4': (218, 213, 288, 253),
 'fedw0_sa2': (219, 205, 289, 245),
 'fedw0_si1084': (219, 195, 289, 235),
 'faks0_sx223': (211, 214, 281, 254),
 'faks0_sa1': (225, 248, 295, 288),
 'faks0_si943': (217, 241, 287, 281),
 'faks0_sx313': (203, 220, 273, 260),
 'faks0_sx133': (219, 240, 289, 280),
 'faks0_sx43': (219, 208, 289, 248),
 'faks0_si2203': (222, 247, 292, 287),
 'faks0_si1573': (221, 242, 291, 282),
 'fram1_si1360': (217, 249, 287, 289),
 'fram1_sa1': (225, 253, 295, 293),
 'fram1_sa2': (225, 237, 295, 277),
 'fram1_sx190': (222, 213, 292, 253),
 'fram1_si522': (225, 262, 295, 302),
 'fram1_sx370': (219, 230, 289, 270),
 'fram1_sx10': (229, 253, 299, 293),
 'fram1_sx100': (223, 218, 293, 258),
 'fram1_si730': (222, 262, 292, 302),
 'fram1_sx280': (216, 234, 286, 274),
 'fdrd1_sx374': (218, 212, 288, 252),
 'fdrd1_sa1': (224, 244, 294, 284),
 'fdrd1_sa2': (228, 229, 298, 269),
 'fdrd1_si1544': (221, 242, 291, 282),
 'fdrd1_si1566': (217, 241, 287, 281),
 'fdrd1_sx14': (214, 188, 284, 228),
 'fdrd1_sx104': (218, 244, 288, 284),
 'fdrd1_sx194': (217, 196, 287, 236),
 'fdrd1_sx284': (222, 205, 292, 245),
 'mrjo0_sx104': (202, 217, 272, 257),
 'mrjo0_sx194': (224, 233, 294, 273),
 'mrjo0_si734': (211, 227, 281, 267),
 'mrjo0_si1624': (208, 229, 278, 269),
 'mrjo0_sa1': (212, 217, 282, 257),
 'mrjo0_sa2': (215, 232, 285, 272),
 'mrjo0_sx284': (221, 252, 291, 292),
 'mrjo0_sx14': (225, 228, 295, 268),
 'mrjo0_sx374': (215, 267, 285, 307),
 'fjem0_sx4': (221, 215, 291, 255),
 'fjem0_si1894': (228, 254, 298, 294),
 'fjem0_sx274': (231, 224, 301, 264),
 'fjem0_si1264': (225, 255, 295, 295),
 'fjem0_sx184': (211, 248, 281, 288),
 'fjem0_sx364': (226, 236, 296, 276),
 'fjem0_sa1': (210, 236, 280, 276),
 'fjem0_sa2': (215, 259, 285, 299),
 'fjem0_si634': (228, 253, 298, 293),
 'mmdm2_sx102': (219, 233, 289, 273),
 'mmdm2_si1555': (216, 240, 286, 280),
 'mmdm2_sa1': (211, 236, 281, 276),
 'mmdm2_si1425': (209, 239, 279, 279),
 'mmdm2_si2028': (218, 239, 288, 279),
 'mmdm2_sa2': (214, 238, 284, 278),
 'mmdm2_sx282': (224, 204, 294, 244),
 'mmdm2_sx12': (225, 213, 295, 253),
 'mmdm2_sx372': (226, 198, 296, 238),
 'fcmr0_si475': (225, 229, 295, 269),
 'fcmr0_sx295': (223, 232, 293, 272),
 'fcmr0_si1105': (221, 231, 291, 271),
 'fcmr0_sa1': (226, 245, 296, 285),
 'fcmr0_sx115': (224, 239, 294, 279),
 'fcmr0_sx385': (222, 231, 292, 271),
 'fcmr0_sx205': (221, 228, 291, 268),
 'fcmr0_sx25': (221, 242, 291, 282)}

# %%
for i in cropping_dictionary:
  a,b,c,d =  cropping_dictionary[i]
  cropping_dictionary[i] = (a-10,b-5,c+10,d+5)
cropping_dictionary
# Out:
# {'mabw0_si1230': (206, 207, 296, 257),
#  'fjwb0_sx95': (213, 206, 303, 256),
#  'mreb0_sx25': (202, 225, 292, 275),
#  'fdrd1_si2149': (207, 240, 297, 290),
#  'mpdf0_si1542': (228, 217, 318, 267),
#  'mpdf0_sa2': (233, 211, 323, 261),
#  'mpdf0_sa1': (229, 209, 319, 259),
#  'mpdf0_sx192': (211, 197, 301, 247),
#  'mpdf0_sx102': (228, 213, 318, 263),
#  'mpdf0_si2172': (228, 215, 318, 265),
#  'mpdf0_si912': (229, 215, 319, 265),
#  'mreb0_sx295': (208, 212, 298, 262),
#  'mreb0_sa2': (208, 239, 298, 289),
#  'mreb0_sa1': (207, 236, 297, 286),
#  'mreb0_si745': (192, 234, 282, 284),
#  'mreb0_sx115': (202, 234, 292, 284),
#  'mreb0_sx385': (207, 211, 297, 261),
#  'mreb0_si1375': (213, 276, 303, 326),
#  'mreb0_sx205': (207, 223, 297, 273),
#  'mjar0_si728': (208, 217, 298, 267),
#  'mjar0_si1988': (234, 218, 324, 268),
#  'mjar0_si2247': (234, 217, 324, 267),
#  'mjar0_sa1': (224, 210, 314, 260),
#  'mjar0_sx278': (212, 208, 302, 258),
#  'mjar0_sx188': (205, 226, 295, 276),
# ...

# %%
cropping_dictionary = {'mabw0_si1230': (206, 207, 296, 257),
 'fjwb0_sx95': (213, 206, 303, 256),
 'mreb0_sx25': (202, 225, 292, 275),
 'fdrd1_si2149': (207, 240, 297, 290),
 'mpdf0_si1542': (228, 217, 318, 267),
 'mpdf0_sa2': (233, 211, 323, 261),
 'mpdf0_sa1': (229, 209, 319, 259),
 'mpdf0_sx192': (211, 197, 301, 247),
 'mpdf0_sx102': (228, 213, 318, 263),
 'mpdf0_si2172': (228, 215, 318, 265),
 'mpdf0_si912': (229, 215, 319, 265),
 'mreb0_sx295': (208, 212, 298, 262),
 'mreb0_sa2': (208, 239, 298, 289),
 'mreb0_sa1': (207, 236, 297, 286),
 'mreb0_si745': (192, 234, 282, 284),
 'mreb0_sx115': (202, 234, 292, 284),
 'mreb0_sx385': (207, 211, 297, 261),
 'mreb0_si1375': (213, 276, 303, 326),
 'mreb0_sx205': (207, 223, 297, 273),
 'mjar0_si728': (208, 217, 298, 267),
 'mjar0_si1988': (234, 218, 324, 268),
 'mjar0_si2247': (234, 217, 324, 267),
 'mjar0_sa1': (224, 210, 314, 260),
 'mjar0_sx278': (212, 208, 302, 258),
 'mjar0_sx188': (205, 226, 295, 276),
 'mjar0_sx368': (215, 204, 305, 254),
 'mjar0_sa2': (229, 213, 319, 263),
 'mjar0_sx98': (200, 198, 290, 248),
 'mjar0_sx8': (206, 199, 296, 249),
 'mmdb1_sx275': (208, 193, 298, 243),
 'mmdb1_sa1': (211, 248, 301, 298),
 'mmdb1_si995': (206, 231, 296, 281),
 'mmdb1_si2255': (204, 225, 294, 275),
 'mmdb1_sa2': (208, 244, 298, 294),
 'mmdb1_sx365': (204, 198, 294, 248),
 'mmdb1_sx185': (209, 234, 299, 284),
 'mmdb1_sx5': (206, 187, 296, 237),
 'mmdb1_sx95': (205, 201, 295, 251),
 'mwbt0_sx383': (211, 230, 301, 280),
 'mwbt0_sa1': (201, 249, 291, 299),
 'mwbt0_sa2': (203, 244, 293, 294),
 'mwbt0_sx293': (214, 222, 304, 272),
 'mwbt0_sx23': (210, 228, 300, 278),
 'mwbt0_si923': (208, 248, 298, 298),
 'mwbt0_si1553': (202, 249, 292, 299),
 'mwbt0_sx203': (208, 212, 298, 262),
 'mdab0_si1039': (207, 238, 297, 288),
 'mdab0_sa1': (212, 218, 302, 268),
 'mdab0_sx319': (208, 193, 298, 243),
 'mdab0_si1669': (210, 235, 300, 285),
 'mdab0_sx139': (211, 224, 301, 274),
 'mdab0_si2299': (211, 222, 301, 272),
 'fkms0_si1490': (212, 265, 302, 315),
 'fkms0_sa2': (205, 259, 295, 309),
 'mdab0_sx49': (206, 203, 296, 253),
 'fkms0_sa1': (200, 248, 290, 298),
 'mdab0_sx409': (206, 205, 296, 255),
 'fkms0_sx140': (205, 262, 295, 312),
 'fkms0_sx410': (198, 257, 288, 307),
 'fkms0_sx230': (212, 277, 302, 327),
 'fkms0_si860': (203, 271, 293, 321),
 'fkms0_sx320': (210, 268, 300, 318),
 'fkms0_si2120': (198, 266, 288, 316),
 'mdld0_si1543': (223, 246, 313, 296),
 'mdld0_sa2': (219, 231, 309, 281),
 'mdld0_sx193': (210, 210, 300, 260),
 'mdld0_sa1': (219, 246, 309, 296),
 'mdld0_si913': (221, 238, 311, 288),
 'mdld0_si2173': (227, 243, 317, 293),
 'mdld0_sx13': (211, 226, 301, 276),
 'mdld0_sx373': (204, 217, 294, 267),
 'mdld0_sx283': (208, 214, 298, 264),
 'mjsw0_sa2': (238, 222, 328, 272),
 'mjsw0_sa1': (239, 222, 329, 272),
 'mjsw0_sx290': (215, 204, 305, 254),
 'mjsw0_sx200': (214, 187, 304, 237),
 'mjsw0_sx20': (213, 194, 303, 244),
 'mjsw0_si1640': (239, 222, 329, 272),
 'mjsw0_sx380': (216, 203, 306, 253),
 'mjsw0_si1010': (240, 220, 330, 270),
 'mjsw0_sx110': (235, 216, 325, 266),
 'mbjk0_sx185': (178, 201, 268, 251),
 'mbjk0_si1175': (184, 204, 274, 254),
 'mbjk0_sa2': (193, 209, 283, 259),
 'mbjk0_si545': (176, 196, 266, 246),
 'mbjk0_sx5': (207, 243, 297, 293),
 'mbjk0_sa1': (188, 210, 278, 260),
 'mbjk0_si2128': (183, 199, 273, 249),
 'mbjk0_sx95': (214, 235, 304, 285),
 'mstk0_si1024': (204, 230, 294, 280),
 'mstk0_si2222': (202, 230, 292, 280),
 'mstk0_si2284': (203, 225, 293, 275),
 'mstk0_sx124': (203, 234, 293, 284),
 'mstk0_sx214': (213, 215, 303, 265),
 'mstk0_sx394': (223, 212, 313, 262),
 'mstk0_sx304': (217, 204, 307, 254),
 'mstk0_sx34': (222, 207, 312, 257),
 'mstk0_sa1': (208, 233, 298, 283),
 'fadg0_si1909': (214, 189, 304, 239),
 'fadg0_si649': (204, 188, 294, 238),
 'fadg0_sa2': (208, 182, 298, 232),
 'fadg0_sa1': (211, 191, 301, 241),
 'fadg0_sx109': (207, 198, 297, 248),
 'mrcz0_sa2': (217, 221, 307, 271),
 'mrcz0_si1541': (220, 238, 310, 288),
 'mrcz0_si911': (217, 212, 307, 262),
 'fadg0_sx379': (214, 193, 304, 243),
 'mrcz0_si2171': (220, 210, 310, 260),
 'mrcz0_sa1': (213, 218, 303, 268),
 'fadg0_sx289': (218, 200, 308, 250),
 'mrcz0_sx371': (218, 216, 308, 266),
 'mrcz0_sx191': (210, 207, 300, 257),
 'mrcz0_sx11': (207, 207, 297, 257),
 'mrcz0_sx101': (220, 222, 310, 272),
 'mrcz0_sx281': (219, 219, 309, 269),
 'mccs0_si839': (215, 231, 305, 281),
 'mccs0_sx119': (211, 235, 301, 285),
 'fjwb0_sa2': (212, 198, 302, 248),
 'mccs0_sx299': (209, 245, 299, 295),
 'fjwb0_si1265': (207, 205, 297, 255),
 'mccs0_sa2': (205, 226, 295, 276),
 'mccs0_sx209': (218, 229, 308, 279),
 'fjwb0_sa1': (213, 194, 303, 244),
 'fjwb0_sx185': (196, 209, 286, 259),
 'fjwb0_sx365': (208, 202, 298, 252),
 'fjwb0_sx275': (212, 208, 302, 258),
 'fjwb0_si992': (197, 206, 287, 256),
 'fjwb0_si635': (208, 198, 298, 248),
 'mrgg0_sx389': (220, 236, 310, 286),
 'mrgg0_sx209': (204, 231, 294, 281),
 'mtas1_sx28': (211, 164, 301, 214),
 'mtas1_sx118': (228, 203, 318, 253),
 'mtas1_sx208': (214, 169, 304, 219),
 'mtas1_si838': (231, 199, 321, 249),
 'mtas1_si2098': (231, 199, 321, 249),
 'mabw0_si1664': (204, 197, 294, 247),
 'mabw0_sa1': (206, 206, 296, 256),
 'mabw0_sx314': (228, 209, 318, 259),
 'mabw0_sx44': (210, 192, 300, 242),
 'mabw0_sa2': (202, 205, 292, 255),
 'mabw0_sx134': (207, 207, 297, 257),
 'mabw0_sx224': (221, 208, 311, 258),
 'mabw0_si2294': (209, 204, 299, 254),
 'felc0_sx216': (219, 204, 309, 254),
 'felc0_sx396': (199, 206, 289, 256),
 'felc0_si756': (190, 220, 280, 270),
 'felc0_sx126': (187, 226, 277, 276),
 'felc0_sa1': (204, 222, 294, 272),
 'felc0_si1386': (196, 223, 286, 273),
 'felc0_si2016': (195, 224, 285, 274),
 'fdac1_sx34': (213, 221, 303, 271),
 'fdac1_sx304': (210, 222, 300, 272),
 'fdac1_sx394': (216, 231, 306, 281),
 'fdac1_sx214': (208, 236, 298, 286),
 'fdac1_sx124': (194, 267, 284, 317),
 'fdac1_sa2': (211, 248, 301, 298),
 'fdac1_sa1': (208, 248, 298, 298),
 'fdac1_si844': (191, 266, 281, 316),
 'fpkt0_sx278': (190, 232, 280, 282),
 'fpkt0_sx8': (202, 234, 292, 284),
 'fpkt0_si2168': (205, 243, 295, 293),
 'fpkt0_sa1': (207, 232, 297, 282),
 'fpkt0_sx368': (191, 228, 281, 278),
 'fpkt0_sx98': (196, 231, 286, 281),
 'fcmh0_si2084': (213, 199, 303, 249),
 'fcmh0_sx14': (217, 217, 307, 267),
 'fcmh0_si1454': (214, 207, 304, 257),
 'fcmh0_si824': (208, 197, 298, 247),
 'fcmh0_sa2': (212, 198, 302, 248),
 'fcmh0_sx374': (211, 221, 301, 271),
 'fcmh0_sx284': (211, 214, 301, 264),
 'fcmh0_sx194': (218, 221, 308, 271),
 'fcmh0_sx104': (214, 201, 304, 251),
 'fcmh0_sa1': (213, 207, 303, 257),
 'fedw0_sx184': (209, 189, 299, 239),
 'fedw0_sx274': (201, 184, 291, 234),
 'fedw0_sa1': (213, 192, 303, 242),
 'fedw0_sx94': (214, 206, 304, 256),
 'fedw0_si1714': (210, 203, 300, 253),
 'fedw0_sx4': (208, 208, 298, 258),
 'fedw0_sa2': (209, 200, 299, 250),
 'fedw0_si1084': (209, 190, 299, 240),
 'faks0_sx223': (201, 209, 291, 259),
 'faks0_sa1': (215, 243, 305, 293),
 'faks0_si943': (207, 236, 297, 286),
 'faks0_sx313': (193, 215, 283, 265),
 'faks0_sx133': (209, 235, 299, 285),
 'faks0_sx43': (209, 203, 299, 253),
 'faks0_si2203': (212, 242, 302, 292),
 'faks0_si1573': (211, 237, 301, 287),
 'fram1_si1360': (207, 244, 297, 294),
 'fram1_sa1': (215, 248, 305, 298),
 'fram1_sa2': (215, 232, 305, 282),
 'fram1_sx190': (212, 208, 302, 258),
 'fram1_si522': (215, 257, 305, 307),
 'fram1_sx370': (209, 225, 299, 275),
 'fram1_sx10': (219, 248, 309, 298),
 'fram1_sx100': (213, 213, 303, 263),
 'fram1_si730': (212, 257, 302, 307),
 'fram1_sx280': (206, 229, 296, 279),
 'fdrd1_sx374': (208, 207, 298, 257),
 'fdrd1_sa1': (214, 239, 304, 289),
 'fdrd1_sa2': (218, 224, 308, 274),
 'fdrd1_si1544': (211, 237, 301, 287),
 'fdrd1_si1566': (207, 236, 297, 286),
 'fdrd1_sx14': (204, 183, 294, 233),
 'fdrd1_sx104': (208, 239, 298, 289),
 'fdrd1_sx194': (207, 191, 297, 241),
 'fdrd1_sx284': (212, 200, 302, 250),
 'mrjo0_sx104': (192, 212, 282, 262),
 'mrjo0_sx194': (214, 228, 304, 278),
 'mrjo0_si734': (201, 222, 291, 272),
 'mrjo0_si1624': (198, 224, 288, 274),
 'mrjo0_sa1': (202, 212, 292, 262),
 'mrjo0_sa2': (205, 227, 295, 277),
 'mrjo0_sx284': (211, 247, 301, 297),
 'mrjo0_sx14': (215, 223, 305, 273),
 'mrjo0_sx374': (205, 262, 295, 312),
 'fjem0_sx4': (211, 210, 301, 260),
 'fjem0_si1894': (218, 249, 308, 299),
 'fjem0_sx274': (221, 219, 311, 269),
 'fjem0_si1264': (215, 250, 305, 300),
 'fjem0_sx184': (201, 243, 291, 293),
 'fjem0_sx364': (216, 231, 306, 281),
 'fjem0_sa1': (200, 231, 290, 281),
 'fjem0_sa2': (205, 254, 295, 304),
 'fjem0_si634': (218, 248, 308, 298),
 'mmdm2_sx102': (209, 228, 299, 278),
 'mmdm2_si1555': (206, 235, 296, 285),
 'mmdm2_sa1': (201, 231, 291, 281),
 'mmdm2_si1425': (199, 234, 289, 284),
 'mmdm2_si2028': (208, 234, 298, 284),
 'mmdm2_sa2': (204, 233, 294, 283),
 'mmdm2_sx282': (214, 199, 304, 249),
 'mmdm2_sx12': (215, 208, 305, 258),
 'mmdm2_sx372': (216, 193, 306, 243),
 'fcmr0_si475': (215, 224, 305, 274),
 'fcmr0_sx295': (213, 227, 303, 277),
 'fcmr0_si1105': (211, 226, 301, 276),
 'fcmr0_sa1': (216, 240, 306, 290),
 'fcmr0_sx115': (214, 234, 304, 284),
 'fcmr0_sx385': (212, 226, 302, 276),
 'fcmr0_sx205': (211, 223, 301, 273),
 'fcmr0_sx25': (211, 237, 301, 287)}

# %%
import cv2

# %%
image = cv2.imread('/content/drive/MyDrive/final_lipnet_dataset/fadg0_sa1/010')
image
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-165728da9486> in <cell line: 1>()
# ----> 1 image = cv2.imread('/content/drive/MyDrive/final_lipnet_dataset/fadg0_sa1/010')
#       2 image
#
# NameError: name 'cv2' is not defined

# %%
a,b,c,d = cropping_dictionary['fadg0_sa1']
image[b:d,a:c,:]
# Out:
# array([[[ 86, 118, 171],
#         [ 88, 119, 172],
#         [ 87, 119, 172],
#         ...,
#         [ 86, 123, 181],
#         [ 87, 124, 182],
#         [ 86, 124, 182]],
#
#        [[ 86, 118, 171],
#         [ 88, 119, 172],
#         [ 86, 118, 171],
#         ...,
#         [ 86, 123, 181],
#         [ 87, 124, 182],
#         [ 86, 124, 182]],
#
#        [[ 86, 117, 168],
#         [ 86, 117, 170],
#         [ 84, 116, 169],
#         ...,
#         [ 83, 120, 178],
#         [ 84, 121, 177],
#         [ 83, 122, 177]],
#
#        ...,
#
#        [[ 79, 112, 161],
#         [ 79, 112, 162],
#         [ 76, 111, 161],
#         ...,
#         [ 72, 115, 164],
#         [ 75, 118, 167],
#         [ 79, 122, 171]],
#
#        [[ 78, 114, 162],
#         [ 77, 112, 162],
#         [ 76, 111, 161],
#         ...,
#         [ 73, 116, 167],
#         [ 76, 119, 170],
#         [ 82, 122, 174]],
#
#        [[ 79, 115, 163],
#         [ 77, 111, 164],
#         [ 76, 110, 163],
# ...

# %%
308*150
# Out:
# 46200
